# %%
import pandas as pd

# %%
df=pd.read_csv('purchase_data.csv')

# %%
#PLAYER COUNT
print("PLAYER COUNT:")
print("Total Number of Players:", len(list(df['SN'].unique())) )
print("Purchasing Analysis (Total):", sum(df['Price']) )
print("Number of Unique Items:", len(list(df['Item ID'].unique())) ) 
print("Total Number of Purchases:", df['Purchase ID'].count()) 
print("Average Purchase Price:", sum(df['Price'])/df['Purchase ID'].count())
print("Total Revenue:",sum(df['Price']) )
# Out:
# PLAYER COUNT:
# Total Number of Players: 576
# Purchasing Analysis (Total): 2379.7699999999973
# Number of Unique Items: 179
# Total Number of Purchases: 780
# Average Purchase Price: 3.050987179487176
# Total Revenue: 2379.7699999999973

# %%
#GENDER DEMOGRAPHICS
print("Gender Demographics:")

unique_sn_df=df.drop_duplicates(subset=['SN'])

new_gender_df=unique_sn_df.groupby('Gender', as_index=False).size()


for index, rows in new_gender_df.iterrows():
  print(f"Percentage and Count of {rows['Gender']} Players:")
  print("Count:",rows['size'])
  print("Percentage:", rows['size']/new_gender_df['size'].sum()*100 )
# Out:
# Gender Demographics:
# Percentage and Count of Female Players:
# Count: 81
# Percentage: 14.0625
# Percentage and Count of Male Players:
# Count: 484
# Percentage: 84.02777777777779
# Percentage and Count of Other / Non-Disclosed Players:
# Count: 11
# Percentage: 1.9097222222222223

# %%
#PURCHASING ANALYSIS TOTAL
print("Purchasing Analysis (Gender):")

new_gender_purchasing_df=df.groupby('Gender', as_index=False).size()


for index, rows in new_gender_purchasing_df.iterrows():
  print(f"Purchasing Analysis ({rows['Gender']}):")

  print("Purchase Count:", df[df['Gender']==rows['Gender']]['Purchase ID'].count())
  print("Total Purchase Value:", df[df['Gender']==rows['Gender']]['Price'].sum())
  print("Average Purchase Price:", df[df['Gender']==rows['Gender']]['Price'].sum()/new_gender_df[new_gender_df['Gender']==rows['Gender']]['size'].values[0])

  unique_sn_gender_df=unique_sn_df[unique_sn_df['Gender']==rows['Gender']]['SN'].to_frame() 
  avg_purchase_df=pd.DataFrame(columns = ['SN', 'Gender', 'Average Purchase Total'])
  for i_index, i_rows in unique_sn_gender_df.iterrows():
    avg_purchase_df = avg_purchase_df.append({'SN' :i_rows['SN'] , 'Gender' : rows['Gender'], 'Average Purchase Total' : df[df['SN']==i_rows['SN']]['Price'].sum()/new_gender_df[new_gender_df['Gender']==rows['Gender']]['size'].values[0]}, ignore_index = True)
  print("Average Purchase Total per Person by Gender:")
  print(avg_purchase_df)
# Out:
# Purchasing Analysis (Gender):
# Purchasing Analysis (Female):
# Purchase Count: 113
# Total Purchase Value: 361.94
# Average Purchase Price: 4.468395061728395
# Average Purchase Total per Person by Gender:
#                 SN  Gender  Average Purchase Total
# 0        Lisassa64  Female                0.035679
# 1        Reunasu60  Female                0.108889
# 2         Reulae52  Female                0.051605
# 3        Assosia88  Female                0.016420
# 4        Phaelap26  Female                0.081975
# ..             ...     ...                     ...
# 76  Tyaelistidru84  Female                0.040247
# 77     Yarithrin84  Female                0.051111
# 78       Tyaelly53  Female                0.025556
# 79        Eudanu84  Female                0.012593
# 80      Aethedru70  Female                0.043704
#
# [81 rows x 3 columns]
# Purchasing Analysis (Male):
# Purchase Count: 652
# Total Purchase Value: 1967.64
# Average Purchase Price: 4.065371900826446
# Average Purchase Total per Person by Gender:
#                 SN Gender  Average Purchase Total
# 0          Lisim78   Male                0.020702
# 1      Lisovynya38   Male                0.003223
# 2       Ithergue48   Male                0.010083
# 3    Chamassasya86   Male                0.006756
# 4        Iskosia90   Male                0.002975
# ..             ...    ...                     ...
# 479   Iskossasda43   Male                0.008988
# 480         Hala31   Male                0.002107
# 481     Jiskjask80   Male                0.008657
# 482     Yathecal72   Male                0.007149
# 483        Sisur91   Male                0.008657
#
# [484 rows x 3 columns]
# Purchasing Analysis (Other / Non-Disclosed):
# Purchase Count: 15
# Total Purchase Value: 50.19
# Average Purchase Price: 4.5627272727272725
# Average Purchase Total per Person by Gender:
#               SN                 Gender  Average Purchase Total
# 0    Chanosian48  Other / Non-Disclosed                0.683636
# 1   Siarithria38  Other / Non-Disclosed                0.628182
# 2     Haerithp41  Other / Non-Disclosed                0.400000
# 3       Sundim98  Other / Non-Disclosed                0.431818
# 4    Jiskirran77  Other / Non-Disclosed                0.308182
# 5      Idairin51  Other / Non-Disclosed                0.636364
# 6      Eodaisu60  Other / Non-Disclosed                0.358182
# 7      Rairith81  Other / Non-Disclosed                0.201818
# 8       Lirtim36  Other / Non-Disclosed                0.120909
# 9     Maluncil97  Other / Non-Disclosed                0.480000
# 10        Airi27  Other / Non-Disclosed                0.313636

# %%
#AGE DEMOGRAPHICS
new_age_df=unique_sn_df.groupby('Age', as_index=False).size()

print("Age Demographics:")

print("Age Demographics: age<10")
print("Purchase Count:",df[df['Age']<10]['Purchase ID'].count())
print("Total Purchase Value:", df[df['Age']<10]['Price'].sum())
print("Average Purchase Price:", df[df['Age']<10]['Price'].sum()/len(unique_sn_df[unique_sn_df['Age']<10]))

unique_sn_age_df=unique_sn_df[unique_sn_df['Age']<10][['SN','Age']] 
avg_purchase_byage_df=pd.DataFrame(columns = ['SN', 'Age', 'Average Purchase Total'])
for i_index, i_rows in unique_sn_age_df.iterrows():
  avg_purchase_byage_df = avg_purchase_byage_df.append({'SN' :i_rows['SN'] , 'Age' : i_rows['Age'], 'Average Purchase Total' : df[df['SN']==i_rows['SN']]['Price'].sum()/new_age_df[new_age_df['Age']==i_rows['Age']]['size'].values[0]}, ignore_index = True)
print(f"Average Purchase Total per Person by Age Group: age<10")
print(avg_purchase_byage_df)

avg_purchase_byage_df=pd.DataFrame()

for agenum in range(10,100,5):
  print(f"Age Demographics: age: {agenum}-{agenum+4}")
  if df[(df['Age']>=agenum) & (df['Age']<=(agenum+4))]['Purchase ID'].count()>0:
    print("Purchase Count:",df[(df['Age']>=agenum) & (df['Age']<=(agenum+4))]['Purchase ID'].count())
    print("Total Purchase Value:", df[(df['Age']>=agenum) & (df['Age']<=(agenum+4))]['Price'].sum())  
    print("Average Purchase Price:", df[(df['Age']>=agenum) & (df['Age']<=(agenum+4))]['Price'].sum()/len(unique_sn_df[(unique_sn_df['Age']>=agenum) & (unique_sn_df['Age']<=(agenum+4))]))

    
    unique_sn_age_df=unique_sn_df[(unique_sn_df['Age']>=agenum) & (unique_sn_df['Age']<=(agenum+4))][['SN','Age']] 
    avg_purchase_byage_df=pd.DataFrame(columns = ['SN', 'Age', 'Average Purchase Total'])
    for i_index, i_rows in unique_sn_age_df.iterrows():
      avg_purchase_byage_df = avg_purchase_byage_df.append({'SN' :i_rows['SN'] , 'Age' : i_rows['Age'], 'Average Purchase Total' : df[df['SN']==i_rows['SN']]['Price'].sum()/new_age_df[new_age_df['Age']==i_rows['Age']]['size'].values[0]}, ignore_index = True)
    print(f"Average Purchase Total per Person by Age Group:{agenum}-{agenum+4}")
    print(avg_purchase_byage_df)

  else:
    print("No records")
# Out:
# Age Demographics:
# Age Demographics: age<10
# Purchase Count: 23
# Total Purchase Value: 77.13
# Average Purchase Price: 4.537058823529412
# Average Purchase Total per Person by Age Group: age<10
#                SN Age  Average Purchase Total
# 0         Eusri44   7                0.441429
# 1    Haillyrgue51   7                1.357143
# 2       Seuthep89   8                0.341667
# 3        Heudai45   8                0.578333
# 4      Tyeurith29   8                0.608333
# 5    Anallorgue57   8                0.950000
# 6         Ilmol66   8                1.028333
# 7    Chanossast57   7                0.617143
# 8      Sondossa69   7                0.640000
# 9    Eurithphos97   9                1.137500
# 10     Sondadar26   9                1.617500
# 11  Frichossala54   7                0.440000
# 12     Quilassa66   7                0.604286
# 13      Ililsan66   9                0.712500
# 14     Chadjask77   8                0.821667
# 15    Quaecjask96   9                1.100000
# 16        Sisur91   7                0.598571
# Age Demographics: age: 10-14
# Purchase Count: 28
# Total Purchase Value: 82.78
# Average Purchase Price: 3.7627272727272727
# Average Purchase Total per Person by Age Group:10-14
#                SN Age  Average Purchase Total
# 0      Lirtossa84  11                0.540000
# 1      Aeralria27  10                0.584286
# 2        Reulae52  10                0.597143
# 3      Zhisrisu83  10                1.127143
# 4        Raesty92  12                2.182500
# 5    Mindadaran26  13                1.250000
# 6        Lisasi93  13                1.160000
# 7      Aillyrin83  10                0.412857
# 8         Sidap51  11                0.706667
# 9   Lassassasda30  12                0.885000
# 10       Lisico81  10                0.598571
# 11        Siana77  12                0.492500
# 12      Iarilis73  10                0.784286
# 13   Ethralista69  13                0.740000
# 14    Raillydeu47  14                0.985000
# 15  Chanirrasta87  14                2.470000
# 16     Lirtirra81  12                0.390000
# 17         Iana95  10                0.442857
# 18     Eosurdru76  11                0.298333
# 19    Ilastilis78  11                0.328333
# 20    Lisjaskan36  11                0.560000
# 21     Jiskjask80  11                0.698333
# Age Demographics: age: 15-19
# Purchase Count: 136
# Total Purchase Value: 412.89
# Average Purchase Price: 3.858785046728972
# Average Purchase Total per Person by Age Group:15-19
#                 SN Age  Average Purchase Total
# 0           Idai61  19                0.484118
# 1         Sondim73  19                0.258824
# 2    Aidaillodeu39  18                0.374286
# 3         Yaliru88  19                0.178235
# 4       Jiskimya77  17                0.314737
# ..             ...  ..                     ...
# 102  Mindjasksya61  17                0.136842
# 103      Eratiel90  18                0.219048
# 104        Irith83  18                0.098571
# 105      Ilosian36  15                0.176154
# 106   Iskossasda43  16                0.181250
#
# [107 rows x 3 columns]
# Age Demographics: age: 20-24
# Purchase Count: 365
# Total Purchase Value: 1114.06
# Average Purchase Price: 4.318062015503876
# Average Purchase Total per Person by Age Group:20-24
#                 SN Age  Average Purchase Total
# 0          Lisim78  20                0.145217
# 1       Ithergue48  24                0.101667
# 2    Chamassasya86  24                0.068125
# 3        Iskosia90  23                0.029388
# 4          Yalae81  22                0.136531
# ..             ...  ..                     ...
# 253       Iljask75  22                0.073673
# 254        Ilast79  20                0.029710
# 255         Hala31  21                0.023721
# 256     Aethedru70  21                0.082326
# 257     Yathecal72  20                0.050145
#
# [258 rows x 3 columns]
# Age Demographics: age: 25-29
# Purchase Count: 101
# Total Purchase Value: 292.99999999999994
# Average Purchase Price: 3.8051948051948044
# Average Purchase Total per Person by Age Group:25-29
#               SN Age  Average Purchase Total
# 0      Lisirra87  29                0.423000
# 1      Yasrisu92  27                0.382222
# 2      Phaelap26  25                0.154419
# 3   Chamirraya83  25                0.051628
# 4      Pheodai94  29                0.156000
# ..           ...  ..                     ...
# 72    Tyarithn67  27                0.126667
# 73        Asty82  25                0.071860
# 74    Phiristi62  25                0.041628
# 75     Lisilsa62  25                0.113488
# 76  Lisassasta50  25                0.045116
#
# [77 rows x 3 columns]
# Age Demographics: age: 30-34
# Purchase Count: 73
# Total Purchase Value: 214.00000000000003
# Average Purchase Price: 4.115384615384616
# Average Purchase Total per Person by Age Group:30-34
#                 SN Age  Average Purchase Total
# 0        Chamalo71  30                0.185600
# 1          Siala43  30                0.290400
# 2       Idaisuir85  30                0.126000
# 3      Iaralrgue74  33                0.358889
# 4      Ilosianya35  32                0.473333
# 5         Yadanu52  34                0.340000
# 6       Yadaphos40  30                0.214000
# 7       Philodil43  33                0.143333
# 8       Lirtosia63  34                0.612857
# 9       Umolrian85  32                1.355000
# 10      Qarirwen82  33                0.171111
# 11      Laedallo55  30                0.196000
# 12    Pheodaisun84  30                0.332400
# 13       Ethriel85  30                0.124000
# 14       Rarallo90  33                1.005556
# 15        Eyista89  34                0.184286
# 16      Sundadar27  31                1.742000
# 17  Caesrinusuir82  30                0.207200
# 18       Fironon91  30                0.163200
# 19      Lassjask63  30                0.077600
# 20        Syathe73  30                0.056000
# 21      Chadista79  30                0.334000
# 22      Chanosia60  31                1.084000
# 23       Aelollo59  33                0.625556
# 24       Ealrion88  30                0.179200
# 25      Eodailis27  30                0.230400
# 26     Smaistysu35  30                0.267600
# 27     Chamastya76  34                0.292857
# 28       Undirra73  34                0.412857
# 29    Chadadarla74  30                0.241200
# 30     Undjaskla97  33                0.591111
# 31      Undimsya85  33                0.384444
# 32        Ilimya66  33                0.470000
# 33          Yalo85  34                0.521429
# 34        Ardcil81  34                0.797143
# 35      Lisiriya82  32                0.378333
# 36         Eolan54  30                0.061600
# 37           Ina92  31                0.916000
# 38      Sundjask71  32                0.666667
# 39        Alaesu77  30                0.099600
# 40       Eodairu79  32                0.566667
# 41         Aesri53  31                0.352000
# 42       Marynde90  30                0.212400
# 43      Seolollo93  30                0.136400
# 44       Chamast86  32                0.341667
# 45    Chamistast30  31                0.716000
# 46        Idacal95  30                0.082800
# 47      Yalaeria91  33                0.117778
# 48      Yarolwen77  30                0.177200
# 49     Yarithrin84  30                0.165600
# 50    Chanilsast61  30                0.083200
# 51       Aidaira26  30                0.169200
# Age Demographics: age: 35-39
# Purchase Count: 41
# Total Purchase Value: 147.67
# Average Purchase Price: 4.763548387096773
# Average Purchase Total per Person by Age Group:35-39
#                 SN Age  Average Purchase Total
# 0        Itheria73  36                0.436000
# 1      Chanosian48  35                0.752000
# 2      Saesrideu94  35                0.918000
# 3     Siarithria38  38                1.382000
# 4      Farusrian86  37                0.896000
# 5       Tyaerith73  36                0.342000
# 6     Lisossanya98  37                0.688000
# 7      Adastirin33  35                0.448000
# 8      Hailaphos89  35                0.381000
# 9          Lamil79  38                1.858000
# 10       Minduri31  39                0.678333
# 11     Maradaran90  35                0.273000
# 12       Phistym51  37                1.900000
# 13     Qilanrion65  37                0.606000
# 14       Cosadar58  38                0.870000
# 15        Tyaelo67  39                0.813333
# 16    Assassasta79  38                1.326000
# 17     Ilirrasda54  37                1.012000
# 18    Saistyphos30  35                1.033000
# 19         Firon67  35                0.353000
# 20      Sastydeu50  35                0.218000
# 21        Aidain51  39                0.575000
# 22  Aerithnuphos61  39                0.818333
# 23          Isri34  38                1.394000
# 24      Eustyria89  39                0.475000
# 25    Lisassasda39  36                0.588000
# 26       Ealiril69  35                0.440000
# 27         Eusur90  36                0.320000
# 28   Mindirranya33  35                0.387000
# 29      Chanista95  39                0.526667
# 30  Frichirranya75  36                0.846000
# Age Demographics: age: 40-44
# Purchase Count: 12
# Total Purchase Value: 36.54
# Average Purchase Price: 3.321818181818182
# Average Purchase Total per Person by Age Group:40-44
#               SN Age  Average Purchase Total
# 0    Lisovynya38  40                   0.312
# 1       Eyrian71  40                   1.038
# 2     Jiskjask85  40                   0.266
# 3     Isursuir31  44                   1.695
# 4    Hiasurria41  41                   0.805
# 5     Mindossa76  41                   2.465
# 6      Salilis27  40                   0.846
# 7     Frichaya88  42                   3.930
# 8      Inasuir29  40                   0.880
# 9        Aeral68  43                   4.000
# 10  Chanosiaya39  44                   0.985
# Age Demographics: age: 45-49
# Purchase Count: 1
# Total Purchase Value: 1.7
# Average Purchase Price: 1.7
# Average Purchase Total per Person by Age Group:45-49
#         SN Age  Average Purchase Total
# 0  Assim27  45                     1.7
# Age Demographics: age: 50-54
# No records
# Age Demographics: age: 55-59
# No records
# Age Demographics: age: 60-64
# No records
# Age Demographics: age: 65-69
# No records
# Age Demographics: age: 70-74
# No records
# Age Demographics: age: 75-79
# No records
# Age Demographics: age: 80-84
# No records
# Age Demographics: age: 85-89
# No records
# Age Demographics: age: 90-94
# No records
# Age Demographics: age: 95-99
# No records

# %%
#TOP SPENDERS
print("Top Spenders:")


top_spender=df.groupby(['SN'], as_index=False).sum().sort_values('Price', ascending=False).head(5)

top_spender_df=pd.DataFrame(columns = ['SN', 'Purchase Count', 'Average Purchase Price','Total Purchase Value'])

for index,rows in top_spender.iterrows():
  top_spender_df = top_spender_df.append({'SN' : rows['SN'], 'Purchase Count' : df[df['SN']==rows['SN']]['Purchase ID'].count(), 'Average Purchase Price' : rows['Price']/df['Purchase ID'].count(), 'Total Purchase Value' : rows['Price']}, ignore_index = True)

print(top_spender_df)
# Out:
# Top Spenders:
#             SN Purchase Count  Average Purchase Price  Total Purchase Value
# 0    Lisosia93              5                0.024308                 18.96
# 1  Idastidru52              4                0.019808                 15.45
# 2   Chamjask73              3                0.017731                 13.83
# 3       Iral74              4                0.017462                 13.62
# 4  Iskadarya95              3                0.016795                 13.10

# %%
#MOST POPULAR ITEMS
print("Most Popular Items:")

most_popular_item=df.groupby(['Item ID','Item Name'], as_index=False).size().sort_values('size', ascending=False).head(5)

most_popular_item_df=pd.DataFrame(columns = ['Item ID', 'Item Name', 'Purchase Count','Item Price','Total Purchase Value'])

for index,rows in most_popular_item.iterrows():
  get_highest_occurance_price=df[df['Item ID']==rows['Item ID']][['Item ID','Price']].groupby(['Item ID','Price'], as_index=False).size()['size'].nlargest(1).values[0]

  get_occurance_price_df=df[df['Item ID']==rows['Item ID']][['Item ID','Price']].groupby(['Item ID','Price'], as_index=False).size() 

  most_popular_item_df = most_popular_item_df.append({'Item ID' : rows['Item ID'], 'Item Name' :rows['Item Name'], 'Purchase Count' : rows['size'],'Item Price' : get_occurance_price_df[get_occurance_price_df['size']==get_highest_occurance_price]['Price'].values[0] ,'Total Purchase Value' : df[df['Item ID']==rows['Item ID']]['Price'].sum()}, ignore_index = True)
print(most_popular_item_df)
# Out:
# Most Popular Items:
#   Item ID                                     Item Name Purchase Count  \
# 0      92                                  Final Critic             13
# 1     178  Oathbreaker, Last Hope of the Breaking Storm             12
# 2     145                          Fiery Glass Crusader              9
# 3     132                                    Persuasion              9
# 4     108     Extraction, Quickblade Of Trembling Hands              9
#
#    Item Price  Total Purchase Value
# 0        4.88                 59.99
# 1        4.23                 50.76
# 2        4.58                 41.22
# 3        3.19                 28.99
# 4        3.53                 31.77

# %%
#MOST PROFITABLE ITEMS 
print("Most Profitable Items:")


most_profitable_item=df.groupby(['Item ID','Item Name'], as_index=False).sum().sort_values('Price', ascending=False).head(5)

most_profitable_item_df=pd.DataFrame(columns = ['Item ID', 'Item Name', 'Purchase Count','Item Price','Total Purchase Value'])

for index,rows in most_profitable_item.iterrows():
  get_highest_occurance_price=df[df['Item ID']==rows['Item ID']][['Item ID','Price']].groupby(['Item ID','Price'], as_index=False).size()['size'].nlargest(1).values[0]

  get_occurance_price_df=df[df['Item ID']==rows['Item ID']][['Item ID','Price']].groupby(['Item ID','Price'], as_index=False).size()

  most_profitable_item_df = most_profitable_item_df.append({'Item ID' : rows['Item ID'], 'Item Name' :rows['Item Name'], 'Purchase Count' : 0,'Item Price' : get_occurance_price_df[get_occurance_price_df['size']==get_highest_occurance_price]['Price'].values[0] ,'Total Purchase Value' : rows['Price']}, ignore_index = True)

print(most_profitable_item_df)
# Out:
# Most Profitable Items:
#   Item ID                                     Item Name Purchase Count  \
# 0      92                                  Final Critic              0
# 1     178  Oathbreaker, Last Hope of the Breaking Storm              0
# 2      82                                       Nirvana              0
# 3     145                          Fiery Glass Crusader              0
# 4     103                                Singed Scalpel              0
#
#    Item Price  Total Purchase Value
# 0        4.88                 59.99
# 1        4.23                 50.76
# 2        4.90                 44.10
# 3        4.58                 41.22
# 4        4.35                 34.80
